# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# Настраиваем конфигурацию графиков, которые мы создадим

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) 

# Читаем данные 

df = pd.read_csv(r'C:\Users\moshr\Downloads\movies.csv')

# %%
# Выводим первые несколько данных (по умолчанию - 5)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Смотрим, есть ли отсутствующие данные
# Применяем форматированные строки для увеличения наглядности отображения

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {:2.2}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.01%
# genre - 0.0%
# year - 0.0%
# released - 0.00026%
# score - 0.00039%
# votes - 0.00039%
# director - 0.0%
# writer - 0.00039%
# star - 0.00013%
# country - 0.00039%
# budget - 0.28%
# gross - 0.025%
# company - 0.0022%
# runtime - 0.00052%

# %%
# Оцениваем типы данных

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Изменяем формат столбцов для работы с ними, предвательно заменив значения NaN в датафрейме на 0

df = df.fillna(0)
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
# Дата релиза (released) и год релиза (year) различаются, исправляем

df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype('str')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#  Гипотеза: Бюджет (budget) будет иметь высокую корреляцию c Кассовыми сборами (gross)

# %%
# Точечный график Бюджет (budget) и Кассовые сборы (gross)

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget')

plt.ylabel('Gross Earnings')

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                               released  score      votes       director  \
# 5445  December 18 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# График Бюджет (budget) и Кассовые сборы (gross), с использованием seaborn

sns.set_style('white')
sns.color_palette('rocket', as_cmap=True)
sns.relplot(data=df, x='budget', y='gross', hue='score', palette='viridis',)

# %%
# Рассмотрение корреляций

# %%
df.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# Отмечаем высокую корреляцию между Бюджетом (budget) и Кассовыми сборами (gross). Гипотеза - верна.

corr = df.corr()
corr.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_80430_row0_col0, #T_80430_row1_col1, #T_80430_row2_col2, #T_80430_row3_col3, #T_80430_row4_col4, #T_80430_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_80430_row0_col1, #T_80430_row5_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_80430_row0_col2, #T_80430_row0_col5, #T_80430_row1_col0, #T_80430_row1_col3, #T_80430_row1_col4, #T_80430_row3_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_80430_row0_col3 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_80430_row0_col4 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_80430_row1_col2 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_80430_row1_col5 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_80430_row2_col0 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_80430_row2_col1 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_80430_row2_col3 {
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True, cmap='crest')

plt.title('Correlation metrics for numerc features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Рассмотрим Кинокомпании (company)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True, cmap='rocket_r')

plt.title('Correlation metrics for numeric features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()
